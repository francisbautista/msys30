# %% [markdown]
# # Problem Set 1 MSYS30
#
# Using the lessons on search and recursion, answer the ff guide questions using code and comments for your remarks. You may work in at most pairs. Submit the problem set via .ipynb file with your pair's surnames (bautista_santos_pset1.ipynb) via email at fbautista@aten
#
# Feel free to ask any questions re: the mechanics of the PSet.

# %% [markdown]
# ### Problem 1
#
# Given the approach below to do exponentiation recursively, modify it to work using the following algorithm.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Modify the code here to work accordingly 
# and explain via comments or in a new cell why it works (3pts)

def exponent(base, power):
    if power == 0:
        return 1
    else:
        return base*exponent(base, power-1)

# %% [markdown]
# ### Problem 2
#
# Develop a basic binary search algorithm that takes in any list **A**, sorts it using Python's native `.sort()` function, and searches for a target **v** and returns its index in the list or **-1** if not inside the list. Utilize the pseudocode describing Binary Search as follows:

# %% [markdown]
# **Binary Search (A, v)**
#
# **Input**: A Sorted Array A of n numbers, search target V
#
# **Output**: position i where A[i] = v, -1 if not found
# ```
# low ← 0, high ← n-1
# while low <= high do
#    mid ← (low+high)/2
#    if A[mid]= v then
#        return mid
#    else if A[mid] < v then
#        low ← mid+1
#    else
#        high ← mid-1
# return -1
# ```

# %%
# You may modify the code here below for the problem set solution:
# Add comments to explain how your code works (7pts) 

def b_search(A, v):
    # write your code here
    return pos

# %% [markdown]
# ### Bonus:
# What is the worst case, average case, and best case runtimes for *your* implementation of binary search? (2pts)
